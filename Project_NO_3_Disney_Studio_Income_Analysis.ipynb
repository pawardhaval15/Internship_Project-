# %% [markdown]
# Disney studio income analysis

# %%
#import l
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
movie = pd.read_csv("/content/disney_movies.csv")

# %%
df = pd.DataFrame(movie)

# %%
df.isnull()
# Out:
#      movie_title  release_date  genre  mpaa_rating  total_gross  \
# 0          False         False  False        False        False
# 1          False         False  False        False        False
# 2          False         False  False        False        False
# 3          False         False  False        False        False
# 4          False         False  False        False        False
# ..           ...           ...    ...          ...          ...
# 574        False         False  False        False        False
# 575        False         False  False        False        False
# 576        False         False  False        False        False
# 577        False         False  False        False        False
# 578        False         False  False        False        False
#
#      inflation_adjusted_gross
# 0                       False
# 1                       False
# 2                       False
# 3                       False
# 4                       False
# ...

# %%
print(df.release_date)
# Out:
# 0      1937-12-21
# 1      1940-02-09
# 2      1940-11-13
# 3      1946-11-12
# 4      1950-02-15
#           ...
# 574    2016-09-02
# 575    2016-09-23
# 576    2016-11-04
# 577    2016-11-23
# 578    2016-12-16
# Name: release_date, Length: 579, dtype: object

# %%
print(df.total_gross)
# Out:
# 0      184925485
# 1       84300000
# 2       83320000
# 3       65000000
# 4       85000000
#          ...
# 574     12545979
# 575      8874389
# 576    232532923
# 577    246082029
# 578    529483936
# Name: total_gross, Length: 579, dtype: int64

# %%
sns.countplot(movie['release_date'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
movie.head(550)
# Out:
#                          movie_title release_date        genre mpaa_rating  \
# 0    Snow White and the Seven Dwarfs   1937-12-21      Musical           G
# 1                          Pinocchio   1940-02-09    Adventure           G
# 2                           Fantasia   1940-11-13      Musical           G
# 3                  Song of the South   1946-11-12    Adventure           G
# 4                         Cinderella   1950-02-15        Drama           G
# ..                               ...          ...          ...         ...
# 545                            Bears   2014-04-18  Documentary           G
# 546               Million Dollar Arm   2014-05-10        Drama          PG
# 547                       Maleficent   2014-05-30    Adventure          PG
# 548          Planes: Fire and Rescue   2014-07-18    Adventure          PG
# 549          Guardians of the Galaxy   2014-08-01    Adventure       PG-13
#
#      total_gross  inflation_adjusted_gross
# ...

# %%
movie.drop_duplicates(subset=['genre'])
# Out:
#                                 movie_title release_date                genre  \
# 0           Snow White and the Seven Dwarfs   1937-12-21              Musical
# 1                                 Pinocchio   1940-02-09            Adventure
# 4                                Cinderella   1950-02-15                Drama
# 8                            101 Dalmatians   1961-01-25               Comedy
# 20   The Many Adventures of Winnie the Pooh   1977-03-11                  NaN
# 29                                Condorman   1981-08-07               Action
# 34          Something Wicked This Way Comes   1983-04-29               Horror
# 58                        Can't Buy Me Love   1987-08-14      Romantic Comedy
# 63                                   D.O.A.   1988-03-18    Thriller/Suspense
# 164                               Tombstone   1993-12-25              Western
# 261                     Grosse Pointe Blank   1997-04-11         Black Comedy
# ...

# %%
print(len('col(genre)'))
# Out:
# 10
